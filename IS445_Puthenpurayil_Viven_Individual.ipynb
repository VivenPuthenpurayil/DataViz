# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# This is a dataset of all the superbowl winners in every superbowl played up till 2020 so from superwbowl 1 to 54. The dataset includes the date the match was played: string, the superwbowl number: string, the winner: string, the points the winner scored: int, the loser: string, the points the loser scored: int, the MVP: string, the stadium: string, the city: string, and the state: string. We are going to look at this data in reverse so when constructing graphs we can go in the order from the first superbowl to the last one.

# %% [markdown]
# Datasource:
#
# Superbowl History 1967 - 2020: https://www.kaggle.com/datasets/timoboz/superbowl-history-1967-2020
#
# License: CC0: Public Domain

# %%
df = pd.read_csv('superbowl.csv')
df
# Out:
#            Date            SB                Winner  Winner Pts  \
# 0    Feb 2 2020      LIV (54)    Kansas City Chiefs          31
# 1    Feb 3 2019     LIII (53)  New England Patriots          13
# 2    Feb 4 2018      LII (52)   Philadelphia Eagles          41
# 3    Feb 5 2017       LI (51)  New England Patriots          34
# 4    Feb 7 2016            50        Denver Broncos          24
# 5    Feb 1 2015     XLIX (49)  New England Patriots          28
# 6    Feb 2 2014   XLVIII (48)      Seattle Seahawks          43
# 7    Feb 3 2013    XLVII (47)      Baltimore Ravens          34
# 8    Feb 5 2012     XLVI (46)       New York Giants          21
# 9    Feb 6 2011      XLV (45)     Green Bay Packers          31
# 10   Feb 7 2010     XLIV (44)    New Orleans Saints          31
# 11   Feb 1 2009    XLIII (43)   Pittsburgh Steelers          27
# 12   Feb 3 2008     XLII (42)       New York Giants          17
# 13   Feb 4 2007      XLI (41)    Indianapolis Colts          29
# ...

# %%
df_r = df.iloc[::-1]
df_r
# Out:
#            Date            SB                Winner  Winner Pts  \
# 53  Jan 15 1967         I (1)     Green Bay Packers          35
# 52  Jan 14 1968        II (2)     Green Bay Packers          33
# 51  Jan 12 1969       III (3)         New York Jets          16
# 50  Jan 11 1970        IV (4)    Kansas City Chiefs          23
# 49  Jan 17 1971         V (5)       Baltimore Colts          16
# 48  Jan 16 1972        VI (6)        Dallas Cowboys          24
# 47  Jan 14 1973       VII (7)        Miami Dolphins          14
# 46  Jan 13 1974      VIII (8)        Miami Dolphins          24
# 45  Jan 12 1975        IX (9)   Pittsburgh Steelers          16
# 44  Jan 18 1976        X (10)   Pittsburgh Steelers          21
# 43   Jan 9 1977       XI (11)       Oakland Raiders          32
# 42  Jan 15 1978      XII (12)        Dallas Cowboys          27
# 41  Jan 21 1979     XIII (13)   Pittsburgh Steelers          35
# 40  Jan 20 1980      XIV (14)   Pittsburgh Steelers          31
# ...

# %%
plt.title("Winner's points over time")
plt.xlabel("Year")
plt.ylabel("Points")
plt.ylim(0, 60)
plt.yticks(range(0, 61, 10))
plt.plot(range(1967, 2021), df_r['Winner Pts'])

# %%
plt.title("Loser's points over time")
plt.xlabel("Year")
plt.ylabel("Points")
plt.ylim(0, 60)
plt.yticks(range(0, 61, 10))
plt.plot(range(1967, 2021), df_r['Loser Pts'])

# %%
plt.title("Point differential over time")
plt.xlabel("Year")
plt.ylabel("Points")
plt.ylim(0, 60)
plt.yticks(range(0, 61, 10))
plt.plot(range(1967, 2021), df_r['Winner Pts'] - df_r['Loser Pts'])

# %%
winner_counts = df_r['Winner'].value_counts()
plt.bar(winner_counts.index[:5], winner_counts.values[:5])
plt.title("Top 5 Superbowl winners")
plt.xlabel("Team")
plt.ylabel("# of wins")
plt.plot()
# Out:
# []

# %% [markdown]
# The above graph didn't work because there isn't enough space on the x-axis for all of the names to fit, so to fix this issue I increased the size of the plot for all the names to comfortably fit.

# %%
winner_counts = df_r['Winner'].value_counts()
plt.figure(figsize=(10, 6))
plt.bar(winner_counts.index[:5], winner_counts.values[:5])
plt.title("Top 5 Superbowl winners")
plt.xlabel("Team")
plt.ylabel("# of wins")
plt.plot()
# Out:
# []
