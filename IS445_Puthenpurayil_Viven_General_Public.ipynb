# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# This is a dataset of all the superbowl winners in every superbowl played up till 2020 so from superwbowl 1 to 54. The dataset includes the date the match was played: string, the superwbowl number: string, the winner: string, the points the winner scored: int, the loser: string, the points the loser scored: int, the MVP: string, the stadium: string, the city: string, and the state: string. We are going to look at this data in reverse so when constructing graphs we can go in the order from the first superbowl to the last one.

# %% [markdown]
# Datasource:
#
# Superbowl History 1967 - 2020: https://www.kaggle.com/datasets/timoboz/superbowl-history-1967-2020
#
# License: CC0: Public Domain

# %%
df = pd.read_csv('superbowl.csv')
df.head()
# Out:
#          Date         SB                Winner  Winner Pts  \
# 0  Feb 2 2020   LIV (54)    Kansas City Chiefs          31
# 1  Feb 3 2019  LIII (53)  New England Patriots          13
# 2  Feb 4 2018   LII (52)   Philadelphia Eagles          41
# 3  Feb 5 2017    LI (51)  New England Patriots          34
# 4  Feb 7 2016         50        Denver Broncos          24
#
#                   Loser  Loser Pts              MVP                Stadium  \
# 0   San Francisco 49ers         20  Patrick Mahomes      Hard Rock Stadium
# 1      Los Angeles Rams          3   Julian Edelman  Mercedes-Benz Stadium
# 2  New England Patriots         33       Nick Foles      U.S. Bank Stadium
# 3       Atlanta Falcons         28        Tom Brady            NRG Stadium
# 4     Carolina Panthers         10       Von Miller         Levi's Stadium
#
#             City       State
# 0  Miami Gardens     Florida
# 1        Atlanta     Georgia
# 2    Minneapolis   Minnesota
# 3        Houston       Texas
# ...

# %%
df_r = df.iloc[::-1]
df_r.head()
# Out:
#            Date       SB              Winner  Winner Pts               Loser  \
# 53  Jan 15 1967    I (1)   Green Bay Packers          35  Kansas City Chiefs
# 52  Jan 14 1968   II (2)   Green Bay Packers          33     Oakland Raiders
# 51  Jan 12 1969  III (3)       New York Jets          16     Baltimore Colts
# 50  Jan 11 1970   IV (4)  Kansas City Chiefs          23   Minnesota Vikings
# 49  Jan 17 1971    V (5)     Baltimore Colts          16      Dallas Cowboys
#
#     Loser Pts           MVP            Stadium         City       State
# 53         10   Bart Starr+  Memorial Coliseum  Los Angeles  California
# 52         14   Bart Starr+        Orange Bowl        Miami     Florida
# 51          7   Joe Namath+        Orange Bowl        Miami     Florida
# 50          7   Len Dawson+     Tulane Stadium  New Orleans   Louisiana
# 49         13  Chuck Howley        Orange Bowl        Miami     Florida

# %%
df_wp = df.sort_values(by=['Winner Pts'], ascending=False)
top_5_df_wp = df_wp.head(5)
plt.figure(figsize=(10, 6))
plt.bar(top_5_df_wp['Winner'], top_5_df_wp['Winner Pts'])
plt.ylim(0, 60)
plt.yticks(range(0, 61, 10))
plt.title("Top 5 Highest Scoring Superbowl winners")
plt.xlabel("Team")
plt.ylabel("# of pts scored in win")
plt.plot()
# Out:
# []

# %%
df_wp = df.sort_values(by=['Winner Pts'])
top_5_df_wp = df_wp.head(5)
plt.figure(figsize=(10, 6))
plt.bar(top_5_df_wp['Winner'], top_5_df_wp['Winner Pts'])
plt.ylim(0, 60)
plt.yticks(range(0, 61, 10))
plt.title("Top 5 Lowest Scoring Superbowl winners")
plt.xlabel("Team")
plt.ylabel("# of pts scored in win")
plt.plot()
# Out:
# []

# %%
winner_counts = df_r['City'].value_counts()
plt.figure(figsize=(10, 6))
plt.bar(winner_counts.index[:5], winner_counts.values[:5])
plt.title("Top 5 Superbowl hosting cities")
plt.xlabel("City")
plt.ylabel("# of superbowls hosted")
plt.plot()
# Out:
# []
